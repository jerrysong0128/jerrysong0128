# %% [markdown]
# # 定义函数

# %%
from enum import Enum
 
 
class State(Enum):
 
    CODE = 0                        # 代码
    SLASH = 1                       # 斜杠
    NOTE_MULTILINE = 2              # 多行注释
    NOTE_MULTILINE_STAR = 3         # 多行注释遇到*
    NOTE_SINGLELINE = 4             # 单行注释
    BACKSLASH = 5                   # 拆行注释
    CODE_CHAR = 6                   # 字符
    CHAR_ESCAPE_SEQUENCE = 7        # 字符中的转义字符
    CODE_STRING = 8                 # 字符串
    STRING_ESCAPE_SEQUENCE = 9      # 字符串中的转义字符
    STRIGULA = 10                   # 短横线
 
 
# 删除sql语句中的注释
def delete_sql_note(str):
    # TODO 两种情况："--"与"/*...*/"
    s = ""
    # 初始状态定义为代码
    state = State.CODE
    for c in str:
        if state == State.CODE:
            # 遇到单斜杠
            if c == '/':
                # 将状态改为单斜杠
                state = State.SLASH
            # 遇上短横线
            elif c == "-":
                state = State.STRIGULA
            else:
                s += c
                # 在代码中遇到字符
                if c == '\'':
                    state = State.CODE_CHAR
                # 在代码中遇到字符串
                elif c == '\"':
                    state = State.CODE_STRING
 
        # 如果遇到单横线
        elif state == State.STRIGULA:
            # 后面接着跟一个单横线，则说明是单行注释
            if c == '-':
                state = State.NOTE_SINGLELINE
            # 如果后面跟的是其他字符，则将状态转为代码
            else:
                s += "-" + c
                state = State.CODE
 
        # 遇到单斜杠
        elif state == State.SLASH:
            # 单斜杠后面再遇到*号，则说明是多行注释
            if c == '*':
                state = State.NOTE_MULTILINE
            # 单斜杠后面再遇到单斜杠，说明是单行注释
            elif c == '/':
                state = State.NOTE_SINGLELINE
            # 如果是其他，则将其添加到字符串中
            else:
                s += "/"
                s += c
                state = State.CODE
 
        # 遇到多行注释
        elif state == State.NOTE_MULTILINE:
            # 多行注释后面遇到*号
            if c == '*':
                state = State.NOTE_MULTILINE_STAR
            # 多行注释后面换行了
            else:
                if c == '\n':
                    s += '\r\n'
                # 则当前状态还是多行注释
                state = State.NOTE_MULTILINE
        # 多行注释后面又遇到*号
        elif state == State.NOTE_MULTILINE_STAR:
            # 如果*号后面又是单斜杠在，则说明注释结束了
            if c == '/':
                # 将状态改为代码
                state = State.CODE
            # 如果*号后面又是*号，则说明还是多行注释遇到*
            elif c == '*':
                state = State.NOTE_MULTILINE_STAR
            # 其他情况还是多行注释
            else:
                state = State.NOTE_MULTILINE
        # 单行注释
        elif state == State.NOTE_SINGLELINE:
            if c == '\\':
                state = State.BACKSLASH
            # 如果遇到换行符，则说明单行注释结束了
            elif c == '\n':
                s += '\r\n'
                state = State.CODE
            # 如果是其他情况，则说明单行注释还没有结束
            else:
                state = State.NOTE_SINGLELINE
        # 拆行注释
        elif state == State.BACKSLASH:
            if c == '\\' or c == '\r' or c == '\n':
                if c == '\n':
                    s += '\r\n'
                state = State.BACKSLASH
            else:
                state = State.NOTE_SINGLELINE
        # 代码中遇到单引号
        elif state == State.CODE_CHAR:
            s += c
            # 字符串中的转义字符
            if c == '\\':
                state = State.CHAR_ESCAPE_SEQUENCE
            # 再次遇到单引号，则说明字符串内容结束了。
            elif c == '\'':
                state = State.CODE
            # 如果是其他情况，则还是在字符串中
            else:
                state = State.CODE_CHAR
        # 字符串中遇到转义字符
        elif state == State.CHAR_ESCAPE_SEQUENCE:
            s += c
            state = State.CODE_CHAR
        # 字符串
        elif state == State.CODE_STRING:
            s += c
            if c == '\\':
                state = State.STRING_ESCAPE_SEQUENCE
            # 字符串内容结束
            elif c == '\"':
                state = State.CODE
            else:
                state = State.CODE_STRING
        elif state == State.STRING_ESCAPE_SEQUENCE:
            s += c
            state = State.CODE_STRING
    return s

# %% [markdown]
# # 运行路径

# %%
sql_file = '../data_files/Temoa_Input_US/completed_analyses/Env_Modelling_Software_2015/EMS_base_test.sql'

# %% [markdown]
# # 运行

# %%
if __name__ == '__main__':
    with open(sql_file, 'r', encoding='utf-8') as f:
        f = f.read()
        res = delete_sql_note(f)
        print(res)
# Out:
# BEGIN TRANSACTION;
#
#
#
#
#
#
#
#
#
# CREATE TABLE time_period_labels (
#   t_period_labels text primary key,
#   t_period_labels_desc text);
# INSERT INTO "time_period_labels" VALUES('e', 'existing vintages');
# INSERT INTO "time_period_labels" VALUES('f', 'future');
#
# CREATE TABLE technology_labels (
#   tech_labels text primary key,
#   tech_labels_desc text);
# INSERT INTO "technology_labels" VALUES('r', 'resource technology');
# INSERT INTO "technology_labels" VALUES('p', 'production technology');
# INSERT INTO "technology_labels" VALUES('pb', 'baseload production technology');
# INSERT INTO "technology_labels" VALUES('ps', 'storage production technology');
#
# CREATE TABLE commodity_labels (
#   comm_labels text primary key,
#   comm_labels_desc text);
# INSERT INTO "commodity_labels" VALUES('p', 'physical commodity');
# INSERT INTO "commodity_labels" VALUES('e', 'emissions commodity');
# INSERT INTO "commodity_labels" VALUES('d', 'demand commodity');
#
# CREATE TABLE sector_labels (
#   sector text primary key);
# INSERT INTO "sector_labels" VALUES('supply');
# INSERT INTO "sector_labels" VALUES('electric');
# INSERT INTO "sector_labels" VALUES('transport');
# INSERT INTO "sector_labels" VALUES('commercial');
# INSERT INTO "sector_labels" VALUES('residential');
# INSERT INTO "sector_labels" VALUES('industrial');
#
#
# CREATE TABLE time_periods (
#   t_periods integer primary key,
#   flag text,
#   FOREIGN KEY(flag) REFERENCES time_period_labels(t_period_labels));
# INSERT INTO "time_periods" VALUES(2000,'e');
# INSERT INTO "time_periods" VALUES(2005,'e');
# INSERT INTO "time_periods" VALUES(2010,'e');
# INSERT INTO "time_periods" VALUES(2015,'f');
# INSERT INTO "time_periods" VALUES(2020,'f');
# INSERT INTO "time_periods" VALUES(2025,'f');
# INSERT INTO "time_periods" VALUES(2030,'f');
# INSERT INTO "time_periods" VALUES(2035,'f');
# INSERT INTO "time_periods" VALUES(2040,'f');
# INSERT INTO "time_periods" VALUES(2045,'f');
# INSERT INTO "time_periods" VALUES(2050,'f');
# INSERT INTO "time_periods" VALUES(2055,'f');
#
#
# CREATE TABLE time_season (
#   t_season text primary key );
# INSERT INTO "time_season" VALUES('annual');
#
#
#
#
#
#
# CREATE TABLE time_of_day (
#   t_day text primary key );
# INSERT INTO "time_of_day" VALUES('am');
# INSERT INTO "time_of_day" VALUES('peak');
# INSERT INTO "time_of_day" VALUES('pm');
# INSERT INTO "time_of_day" VALUES('night');
#
#
# CREATE TABLE technologies (
#   tech text primary key,
#   flag text,
#   sector text,
#   tech_desc text,
#   FOREIGN KEY(flag) REFERENCES technology_labels(tech_labels),
#   FOREIGN KEY(sector) REFERENCES sector_labels(sector));
# INSERT INTO "technologies" VALUES('IMPELCDSL',           'r','supply','#imported diesel oil');
# INSERT INTO "technologies" VALUES('IMPELCRFL',           'r','supply','#imported residual fuel oil');
# INSERT INTO "technologies" VALUES('IMPELCBSTMEA',        'r','supply','#imported biomass');
# INSERT INTO "technologies" VALUES('IMPELCMSW',           'r','supply','#imported msw');
# INSERT INTO "technologies" VALUES('IMPELCBIO',           'r','supply','#imported biomass to bioIGCC');
# INSERT INTO "technologies" VALUES('IMPELCCOAB',          'r','supply','#imported bituminous coal');
# INSERT INTO "technologies" VALUES('IMPELCCOAS',          'r','supply','#imported subbituminous coal');
# INSERT INTO "technologies" VALUES('IMPELCCOAL',          'r','supply','#imported lignite coal');
# INSERT INTO "technologies" VALUES('IMPELCNGA',           'r','supply','#imported natural gas');
# INSERT INTO "technologies" VALUES('IMPELCURN',           'r','supply','#imported natural uranium');
# INSERT INTO "technologies" VALUES('IMPTRNDSL',           'r','supply','#imported diesel to transport');
# INSERT INTO "technologies" VALUES('IMPTRNE85',           'r','supply','#imported E85 to transport');
# INSERT INTO "technologies" VALUES('IMPTRNE10',           'r','supply','#imported E10 to transport');
# INSERT INTO "technologies" VALUES('IMPTRNH2',            'r','supply','#imported hydrogen fuel cell to transport');
# INSERT INTO "technologies" VALUES('IMPTRNCNG',           'r','supply','#imported CNG to transport');
#
# INSERT INTO "technologies" VALUES('E_COALSTM_R',         'pb','electric','#existing coal steam power plant');
# INSERT INTO "technologies" VALUES('E_COALSTM_N',         'pb','electric','#new pulverized coal steam power plant');
# INSERT INTO "technologies" VALUES('E_COALIGCC_N',        'pb','electric','#new coal IGCC power plant');
# INSERT INTO "technologies" VALUES('E_COALIGCC_CCS_N',    'pb','electric','#new coal IGCC with CCS power plant');
# INSERT INTO "technologies" VALUES('E_URNLWR_R',          'pb','electric','#existing nuclear LWR power plant');
# INSERT INTO "technologies" VALUES('E_URNLWR_N',          'pb','electric','#new nuclear LWR power plant');
# INSERT INTO "technologies" VALUES('E_HYDCONV_R',         'pb','electric','#existing conventional hydroelectric power plant');
# INSERT INTO "technologies" VALUES('E_HYDREV_R',          'ps','electric','#existing reversible hydroelectric power plant');
# INSERT INTO "technologies" VALUES('E_OILSTM_R',          'p','electric','#existing residual fuel oil steam power plant');
# INSERT INTO "technologies" VALUES('E_DSLCT_R',           'p','electric','#existing diesel combustion turbine power plant');
# INSERT INTO "technologies" VALUES('E_DSLCC_R',           'p','electric','#existing diesel combined cycle power plant');
# INSERT INTO "technologies" VALUES('E_NGASTM_R',          'p','electric','#existing natural gas steam power plant');
# INSERT INTO "technologies" VALUES('E_NGACT_R',           'p','electric','#existing natural gas combustion turbine power plant');
# INSERT INTO "technologies" VALUES('E_NGACC_R',           'p','electric','# existing natural gas combined cycle power plant');
# INSERT INTO "technologies" VALUES('E_NGACT_N',           'p','electric','#new natural gas combustion turbine power plant');
# INSERT INTO "technologies" VALUES('E_NGACC_N',           'p','electric','#new natural gas combined cycle power plant');
# INSERT INTO "technologies" VALUES('E_NGAACT_N',          'p','electric','#new natural gas advanced combustion turbine power plant');
# INSERT INTO "technologies" VALUES('E_NGAACC_N',          'p','electric','#new natural gas advanced combined cycle power plant');
# INSERT INTO "technologies" VALUES('E_NGACC_CCS_N',       'p','electric','#new natural gas combined cycle with CCS power plant');
# INSERT INTO "technologies" VALUES('E_NGA_ALL_N',         'p','electric','#an aggregation of all new NGA-based plants');
# INSERT INTO "technologies" VALUES('E_BIOSTM_R',          'p','electric','#existing biomass steam power plant');
# INSERT INTO "technologies" VALUES('E_BIOIGCC_N',         'p','electric','#new bioIGCC power plant');
# INSERT INTO "technologies" VALUES('E_GEO_R',             'p','electric','#existing geothermal power plant');
# INSERT INTO "technologies" VALUES('E_GEOBCFS_N',         'p','electric','#new geothermal binary cycle & flashed system power plant');
# INSERT INTO "technologies" VALUES('E_MSWSTM_R',          'p','electric','#existing municipal solid waste steam power plant');
# INSERT INTO "technologies" VALUES('E_WND_R',             'p','electric','#existing wind power plant');
# INSERT INTO "technologies" VALUES('E_WNDCL4_N',          'p','electric','#new wind class 4 power plant');
# INSERT INTO "technologies" VALUES('E_WNDCL5_N',          'p','electric','#new wind class 5 power plant');
# INSERT INTO "technologies" VALUES('E_WNDCL6_N',          'p','electric','#new wind class 6 power plant');
# INSERT INTO "technologies" VALUES('E_SOLPV_R',           'p','electric','#existing solar photovoltaic power plant');
# INSERT INTO "technologies" VALUES('E_SOLTH_R',           'p','electric','#existing solar thermal power plant');
# INSERT INTO "technologies" VALUES('E_SOLPVCEN_N',        'p','electric','#new solar photovoltaic centralized power plant');
# INSERT INTO "technologies" VALUES('E_SOLTHCEN_N',        'p','electric','#new solar thermal centralized power plant');
# INSERT INTO "technologies" VALUES('E_EA_COAB',           'p','electric','#co2 emission accounting tech for coal bituminous');
# INSERT INTO "technologies" VALUES('E_EA_COAS',           'p','electric','#co2 emission accounting tech for coal subbituminous');
# INSERT INTO "technologies" VALUES('E_EA_COAL',           'p','electric','#co2 emission accounting tech for coal lignite');
# INSERT INTO "technologies" VALUES('E_CCR_COALSTM_N',     'p','electric','#co2 capture retrofit tech before new coal steam plant');
# INSERT INTO "technologies" VALUES('E_CCR_COALIGCC_N',    'p','electric','#co2 capture retrofit tech before coal IGCC plant');
# INSERT INTO "technologies" VALUES('E_BLND_BITSUBLIG',    'p','electric','#blending tech to collect bit sub lig');
#
# INSERT INTO "technologies" VALUES('O_ELCDEM',            'p','residential','#electricity demand technology for other sectros than transport');
#
# INSERT INTO "technologies" VALUES('T_LDV_CDSL_N',            'p','transport','#new compact diesel vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FDSL_N',            'p','transport','#new full diesel vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_SSDSL_N',           'p','transport','#new small SUV diesel vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_CDSL_HYB_N',        'p','transport','#new compact diesel hybrid vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FDSL_HYB_N',        'p','transport','#new full diesel hybrid vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_SSDSL_HYB_N',       'p','transport','#new small SUV diesel hybrid vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_CE85X_N',           'p','transport','#new compact E85X vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FE85X_N',           'p','transport','#new full E85X vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_SSE85X_N',          'p','transport','#new small SUV E85X vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_CE85X_HYB_N',       'p','transport','#new compact E85X hybrid vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FE85X_HYB_N',       'p','transport','#new full E85X hybrid vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_SSE85X_HYB_N',      'p','transport','#new small SUV E85X hybrid vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_CE85X_PHEV10_N',    'p','transport','#new compact E85X plugin hybrid 10 miles vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FE85X_PHEV10_N',    'p','transport','#new full E85X plugin hybrid 10 miles vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_SSE85X_PHEV10_N',   'p','transport','#new small SUV E85X plugin hybrid 10 miles vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_CE85X_PHEV40_N',    'p','transport','#new compact E85X plugin hybrid 40 miles vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FE85X_PHEV40_N',    'p','transport','#new full E85X plugin hybrid 40 miles vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_SSE85X_PHEV40_N',   'p','transport','#new small SUV E85X plugin hybrid 40 miles vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_MCELC_N',           'p','transport','#new mini compact electric vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_CELC_N',            'p','transport','#new compact electric vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FELC_N',            'p','transport','#new full electric vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_SSELC_N',           'p','transport','#new small SUV electric vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_MCE10_N',           'p','transport','#new mini compact E10 vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_CE10_N',            'p','transport','#new compact E10 vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FE10_N',            'p','transport','#new full E10 vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_SSE10_N',           'p','transport','#new small SUV E10 vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_CE10_HYB_N',        'p','transport','#new compact E10 hybrid vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FE10_HYB_N',        'p','transport','#new full E10 hybrid vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_SSE10_HYB_N',       'p','transport','#new small SUV E10 hybrid vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_CE10_PHEV10_N',     'p','transport','#new compact E10 plugin hybrid 10 miles vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FE10_PHEV10_N',     'p','transport','#new full E10 plugin hybrid 10 miles vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_SSE10_PHEV10_N',    'p','transport','#new small SUV E10 plugin hybrid 10 miles vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_CE10_PHEV40_N',     'p','transport','#new compact E10 plugin hybrid 40 miles vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FE10_PHEV40_N',     'p','transport','#new full E10 plugin hybrid 40 miles vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_SSE10_PHEV40_N',    'p','transport','#new small SUV E10 plugin hybrid 40 miles vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_CH2FC_N',           'p','transport','#new compact hydrogen fuel cell vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FH2FC_N',           'p','transport','#new full hydrogen fuel cell vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_SSH2FC_N',          'p','transport','#new small SUV hydrogen fuel cell vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_CCNG_N',            'p','transport','#new compact CNG vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FCNG_N',            'p','transport','#new full CNG vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_MCE10_R',           'p','transport','#existing mini compact E10 vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_CE10_R',            'p','transport','#existing compact E10 vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FE10_R',            'p','transport','#existing full E10 vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_SSE10_R',           'p','transport','#existing small SUV E10 vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FDSL_R',            'p','transport','#existing full diesel vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FE85X_R',           'p','transport','#existing full E85X vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FELC_R',            'p','transport','#existing full electric vehicle');
# INSERT INTO "technologies" VALUES('T_LDV_FCNG_R',            'p','transport','#existing full CNG vehicle');
# INSERT INTO "technologies" VALUES('T_EA_DSL',                'p','transport','#co2 emission accounting tech for diesel');
# INSERT INTO "technologies" VALUES('T_EA_E85X',               'p','transport','#co2 emission accounting tech for E85');
# INSERT INTO "technologies" VALUES('T_EA_E10',                'p','transport','#co2 emission accounting tech for E10');
# INSERT INTO "technologies" VALUES('T_EA_CNG',                'p','transport','#co2 emission accounting tech for CNG');
# INSERT INTO "technologies" VALUES('T_BLND_E10_PHEV10',       'p','transport','#blending tech to collect E10 and ELC for PHEV10');
# INSERT INTO "technologies" VALUES('T_BLND_E10_PHEV40',       'p','transport','#blending tech to collect E10 and ELC for PHEV40');
# INSERT INTO "technologies" VALUES('T_BLND_E85X_PHEV10',      'p','transport','#blending tech to collect E85 and ELC for PHEV10');
# INSERT INTO "technologies" VALUES('T_BLND_E85X_PHEV40',      'p','transport','#blending tech to collect E85 and ELC for PHEV40');
# INSERT INTO "technologies" VALUES('T_LDV_BLNDDEM',           'p','transport','#blending LDV demand tech for MC-C-F-SS size classes');
#
#
# CREATE TABLE commodities (
#   comm_name text primary key,
#   flag text,
#   comm_desc text,
#   FOREIGN KEY(flag) REFERENCES commodity_labels(comm_labels));
# INSERT INTO "commodities" VALUES('ethos',             'p','# dummy commodity to supply inputs (makes graph easier to read)');
# INSERT INTO "commodities" VALUES('ELC',               'p','# electricity');
# INSERT INTO "commodities" VALUES('ELC_NGA',           'p','# electricity output from NGA-based plants');
# INSERT INTO "commodities" VALUES('COALSTM_R',         'p','# coal to existing steam power plant');
# INSERT INTO "commodities" VALUES('COAB_EA',           'p','# bituminous coal to co2 emission accounting tech');
# INSERT INTO "commodities" VALUES('COAS_EA',           'p','# subbituminous coal to co2 emission accounting tech');
# INSERT INTO "commodities" VALUES('COAL_EA',           'p','# lignite coal to co2 emission accounting tech');
# INSERT INTO "commodities" VALUES('COAB',              'p','# bituminous coal to the blending tech');
# INSERT INTO "commodities" VALUES('COAS',              'p','# subbituminous coal to the blending tech');
# INSERT INTO "commodities" VALUES('COAL',              'p','# lignite coal to the blending tech');
# INSERT INTO "commodities" VALUES('COALSTM_N',         'p','# coal to new steam power plant');
# INSERT INTO "commodities" VALUES('COALSTM_N_CC',      'p','# new coal to co2 emission capture retrofit');
# INSERT INTO "commodities" VALUES('COALIGCC_N',        'p','# coal to new IGCC power plant');
# INSERT INTO "commodities" VALUES('COALIGCC_N_CC',     'p','# coal IGCC to co2 emission capture retrofit');
# INSERT INTO "commodities" VALUES('COALIGCC_CCS_N',    'p','# coal to new IGCC with ccs power plant');
# INSERT INTO "commodities" VALUES('URN_R',             'p','# enriched uranium to existing LWR power plant');
# INSERT INTO "commodities" VALUES('URN_N',             'p','# enriched uranium to new LWR power plant');
# INSERT INTO "commodities" VALUES('HYD_R',             'p','# water to existing conventional hydro power plant');
# INSERT INTO "commodities" VALUES('OIL_R',             'p','# residual fuel oil to existing oil steam power plant');
# INSERT INTO "commodities" VALUES('DSLCT_R',           'p','# diesel oil to existing combustion turbine power plant');
# INSERT INTO "commodities" VALUES('DSLCC_R',           'p','# diesel oil to existing combined cycle power plant');
# INSERT INTO "commodities" VALUES('NGASTM_R',          'p','# natural gas to existing steam power plant');
# INSERT INTO "commodities" VALUES('NGACT_R',           'p','# natural gas to existing combustion turbine power plant');
# INSERT INTO "commodities" VALUES('NGACC_R',           'p','# natural gas to existing combined cycle power plant');
# INSERT INTO "commodities" VALUES('NGACT_N',           'p','# natural gas to new combustion turbine power plant');
# INSERT INTO "commodities" VALUES('NGACC_N',           'p','# natural gas to new combined cycle power plant');
# INSERT INTO "commodities" VALUES('NGAACT_N',          'p','# natural gas to new advanced combustion turbine power plant');
# INSERT INTO "commodities" VALUES('NGAACC_N',          'p','# natural gas to new advanced combined cycle power plant');
# INSERT INTO "commodities" VALUES('NGACC_CCS_N',       'p','# natural gas to new combined cycle with ccs power plant');
# INSERT INTO "commodities" VALUES('BIO_R',             'p','# biomass to existing biomass steam power plant');
# INSERT INTO "commodities" VALUES('BIO_N',             'p','# biomass to new bioIGCC power plant');
# INSERT INTO "commodities" VALUES('GEO',               'p','# geothermal');
# INSERT INTO "commodities" VALUES('MSW',               'p','# municipal solid waste');
# INSERT INTO "commodities" VALUES('WND',               'p','# wind');
# INSERT INTO "commodities" VALUES('SOL',               'p','# solar');
# INSERT INTO "commodities" VALUES('DSL',               'p','# diesel for transport');
# INSERT INTO "commodities" VALUES('DSL_EA',            'p','# diesel to co2 emission accounting');
# INSERT INTO "commodities" VALUES('E85',               'p','# E85 for transport');
# INSERT INTO "commodities" VALUES('E85_EA',            'p','# E85 to co2 emission accounting');
# INSERT INTO "commodities" VALUES('E10',               'p','# E10 for transport');
# INSERT INTO "commodities" VALUES('E10_EA',            'p','# E10 to co2 emission accounting');
# INSERT INTO "commodities" VALUES('H2',                'p','# hydrogen fuel cell for transport');
# INSERT INTO "commodities" VALUES('CNG',               'p','# CNG for transport');
# INSERT INTO "commodities" VALUES('CNG_EA',            'p','# CNG to co2 emission accounting');
# INSERT INTO "commodities" VALUES('E10ELC',            'p','# blend of E10 and ELC for PHEV10 and PHEV40');
# INSERT INTO "commodities" VALUES('E85ELC',            'p','# blend of E85 and ELC for PHEV10 and PHEV40');
# INSERT INTO "commodities" VALUES('TMDLDV_C',          'p','# transport miles demanded for compact LDV');
# INSERT INTO "commodities" VALUES('TMDLDV_F',          'p','# transport miles demanded for full LDV');
# INSERT INTO "commodities" VALUES('TMDLDV_SS',         'p','# transport miles demanded for small SUV LDV');
# INSERT INTO "commodities" VALUES('TMDLDV_MC',         'p','# transport miles demanded for minicompact LDV');
# INSERT INTO "commodities" VALUES('TMDLDV',            'd','# transport miles demanded for LDV');
# INSERT INTO "commodities" VALUES('ELCDEM_NONTRN',     'd','# electricty demand for technologies not in transport sector');
# INSERT INTO "commodities" VALUES('co2',               'e','# CO2 emissions');
#
#
#
#
#
#
#
#
# CREATE TABLE SegFrac (
#    season_name text,
#    time_of_day_name text,
#    segfrac real check (segfrac>=0 AND segfrac<=1),
#    segfrac_notes text,
#    PRIMARY KEY(season_name, time_of_day_name),
#    FOREIGN KEY(season_name) REFERENCES time_season(t_season),
#    FOREIGN KEY(time_of_day_name) REFERENCES time_of_day(t_day) );
# INSERT INTO "SegFrac" VALUES('annual','am',0.25,'# A-DAM from 6am to 12pm'  );
# INSERT INTO "SegFrac" VALUES('annual','peak',0.125,'# A-P from 12pm-3pm'  );
# INSERT INTO "SegFrac" VALUES('annual','pm',0.25,'# A-DPM from 3pm to 9pm'  );
# INSERT INTO "SegFrac" VALUES('annual','night',0.375,'# A-N from 9pm to 6am'  );
#
#
# CREATE TABLE DemandSpecificDistribution (
#    season_name text,
#    time_of_day_name text,
#    demand_name text,
#    dds real check (dds>=0 AND dds<=1),
#    dds_notes text,
#    PRIMARY KEY(season_name, time_of_day_name, demand_name),
#    FOREIGN KEY(season_name) REFERENCES time_season(t_season),
#    FOREIGN KEY(time_of_day_name) REFERENCES time_of_day(t_day),
#    FOREIGN KEY(demand_name) REFERENCES commodities(comm_name) );
#
#
# CREATE TABLE CapacityToActivity (
#    tech text primary key,
#    c2a real,
#    c2a_notes,
#    FOREIGN KEY(tech) REFERENCES technologies(tech) );
# INSERT INTO "CapacityToActivity" VALUES('E_COALSTM_R',31.536,'#PJ/GW');
# INSERT INTO "CapacityToActivity" VALUES('E_COALSTM_N',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_COALIGCC_N',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_COALIGCC_CCS_N',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_URNLWR_R',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_URNLWR_N',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_HYDCONV_R',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_HYDREV_R',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_OILSTM_R',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_DSLCT_R',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_DSLCC_R',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_NGASTM_R',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_NGACT_R',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_NGACT_N',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_NGACC_R',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_NGACC_N',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_NGACC_CCS_N',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_NGAACC_N',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_NGAACT_N',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_NGA_ALL_N',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_BIOSTM_R',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_BIOIGCC_N',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_GEO_R',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_GEOBCFS_N',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_MSWSTM_R',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_WND_R',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_WNDCL4_N',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_WNDCL5_N',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_WNDCL6_N',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_SOLPV_R',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_SOLTH_R',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_SOLPVCEN_N',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_SOLTHCEN_N',31.536,'');
# INSERT INTO "CapacityToActivity" VALUES('E_EA_COAB',1,'');
# INSERT INTO "CapacityToActivity" VALUES('E_EA_COAS',1,'');
# INSERT INTO "CapacityToActivity" VALUES('E_EA_COAL',1,'');
# INSERT INTO "CapacityToActivity" VALUES('E_CCR_COALSTM_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('E_CCR_COALIGCC_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('E_BLND_BITSUBLIG',1,'');
#
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_CDSL_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FDSL_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_SSDSL_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_CDSL_HYB_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FDSL_HYB_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_SSDSL_HYB_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_CE85X_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FE85X_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_SSE85X_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_CE85X_HYB_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FE85X_HYB_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_SSE85X_HYB_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_CE85X_PHEV10_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FE85X_PHEV10_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_SSE85X_PHEV10_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_CE85X_PHEV40_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FE85X_PHEV40_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_SSE85X_PHEV40_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_MCELC_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_CELC_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FELC_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_SSELC_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_MCE10_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_CE10_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FE10_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_SSE10_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_CE10_HYB_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FE10_HYB_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_SSE10_HYB_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_CE10_PHEV10_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FE10_PHEV10_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_SSE10_PHEV10_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_CE10_PHEV40_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FE10_PHEV40_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_SSE10_PHEV40_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_CH2FC_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FH2FC_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_SSH2FC_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_CCNG_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FCNG_N',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_MCE10_R',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_CE10_R',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FE10_R',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_SSE10_R',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FDSL_R',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FE85X_R',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FELC_R',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_FCNG_R',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_BLND_E10_PHEV10',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_BLND_E10_PHEV40',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_BLND_E85X_PHEV10',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_BLND_E85X_PHEV40',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_LDV_BLNDDEM',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_EA_DSL',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_EA_E85X',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_EA_E10',1,'');
# INSERT INTO "CapacityToActivity" VALUES('T_EA_CNG',1,'');
#
# INSERT INTO "CapacityToActivity" VALUES('O_ELCDEM',1,'');
#
#
# CREATE TABLE GlobalDiscountRate (
#    rate real );
# INSERT INTO "GlobalDiscountRate" VALUES(0.05);
#
#
# CREATE TABLE DiscountRate (
#    tech text,
#    vintage integer,
#    tech_rate real,
#    tech_rate_notes text,
#    PRIMARY KEY(tech, vintage),
#    FOREIGN KEY(tech) REFERENCES technologies(tech),
#    FOREIGN KEY(vintage) REFERENCES time_periods(t_periods));
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_CDSL_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CDSL_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CDSL_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CDSL_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CDSL_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CDSL_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CDSL_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_FDSL_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FDSL_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FDSL_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FDSL_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FDSL_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FDSL_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FDSL_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSDSL_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSDSL_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSDSL_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSDSL_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSDSL_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSDSL_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSDSL_N',2050,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CDSL_HYB_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CDSL_HYB_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CDSL_HYB_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CDSL_HYB_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CDSL_HYB_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CDSL_HYB_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CDSL_HYB_N',2050,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FDSL_HYB_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FDSL_HYB_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FDSL_HYB_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FDSL_HYB_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FDSL_HYB_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FDSL_HYB_N',2050,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSDSL_HYB_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSDSL_HYB_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSDSL_HYB_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSDSL_HYB_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSDSL_HYB_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSDSL_HYB_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSDSL_HYB_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_HYB_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_HYB_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_HYB_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_HYB_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_HYB_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_HYB_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_HYB_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_HYB_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_HYB_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_HYB_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_HYB_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_HYB_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_HYB_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_HYB_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_HYB_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_HYB_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_HYB_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_HYB_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_HYB_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_HYB_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_HYB_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_PHEV10_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_PHEV10_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_PHEV10_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_PHEV10_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_PHEV10_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_PHEV10_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_PHEV10_N',2050,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_PHEV10_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_PHEV10_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_PHEV10_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_PHEV10_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_PHEV10_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_PHEV10_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_PHEV10_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_PHEV10_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_PHEV10_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_PHEV10_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_PHEV10_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_PHEV10_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_PHEV10_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_PHEV10_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_PHEV40_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_PHEV40_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_PHEV40_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_PHEV40_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_PHEV40_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_PHEV40_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE85X_PHEV40_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_PHEV40_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_PHEV40_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_PHEV40_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_PHEV40_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_PHEV40_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_PHEV40_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE85X_PHEV40_N',2050,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_PHEV40_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_PHEV40_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_PHEV40_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_PHEV40_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_PHEV40_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_PHEV40_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE85X_PHEV40_N',2050,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_MCELC_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_MCELC_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_MCELC_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_MCELC_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_MCELC_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_MCELC_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_CELC_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CELC_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CELC_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CELC_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CELC_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CELC_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CELC_N',2050,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FELC_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FELC_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FELC_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FELC_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FELC_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FELC_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FELC_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSELC_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSELC_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSELC_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSELC_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSELC_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSELC_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSELC_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_HYB_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_HYB_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_HYB_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_HYB_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_HYB_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_HYB_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_HYB_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_HYB_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_HYB_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_HYB_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_HYB_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_HYB_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_HYB_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_HYB_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_HYB_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_HYB_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_HYB_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_HYB_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_HYB_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_HYB_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_HYB_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_PHEV10_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_PHEV10_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_PHEV10_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_PHEV10_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_PHEV10_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_PHEV10_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_PHEV10_N',2050,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_PHEV10_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_PHEV10_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_PHEV10_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_PHEV10_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_PHEV10_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_PHEV10_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_PHEV10_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_PHEV10_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_PHEV10_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_PHEV10_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_PHEV10_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_PHEV10_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_PHEV10_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_PHEV10_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_PHEV40_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_PHEV40_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_PHEV40_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_PHEV40_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_PHEV40_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_PHEV40_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CE10_PHEV40_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_PHEV40_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_PHEV40_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_PHEV40_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_PHEV40_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_PHEV40_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_PHEV40_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FE10_PHEV40_N',2050,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_PHEV40_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_PHEV40_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_PHEV40_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_PHEV40_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_PHEV40_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_PHEV40_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSE10_PHEV40_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_CH2FC_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CH2FC_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CH2FC_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CH2FC_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CH2FC_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CH2FC_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CH2FC_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_FH2FC_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FH2FC_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FH2FC_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FH2FC_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FH2FC_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FH2FC_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FH2FC_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSH2FC_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSH2FC_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSH2FC_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSH2FC_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSH2FC_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSH2FC_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_SSH2FC_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_CCNG_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CCNG_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CCNG_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CCNG_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CCNG_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CCNG_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_CCNG_N',2050,0.1,'');
#
# INSERT INTO "DiscountRate" VALUES('T_LDV_FCNG_N',2020,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FCNG_N',2025,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FCNG_N',2030,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FCNG_N',2035,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FCNG_N',2040,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FCNG_N',2045,0.1,'');
# INSERT INTO "DiscountRate" VALUES('T_LDV_FCNG_N',2050,0.1,'');
#
#
# CREATE TABLE EmissionActivity  (
#    emis_comm text,
#    input_comm text,
#    tech text,
#    vintage integer,
#    output_comm text,
#    emis_act real,
#    emis_act_units text,
#    emis_act_notes text,
#    PRIMARY KEY(emis_comm, input_comm, tech, vintage, output_comm),
#    FOREIGN KEY(emis_comm) REFERENCES commodities(comm_name),
#    FOREIGN KEY(input_comm) REFERENCES commodities(comm_name),
#    FOREIGN KEY(tech) REFERENCES technologies(tech),
#    FOREIGN KEY(vintage) REFERENCES time_periods(t_periods),
#    FOREIGN KEY(output_comm) REFERENCES commodities(comm_name) );
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPELCDSL',2015,'DSLCT_R',          11.95,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPELCDSL',2015,'DSLCC_R',          11.95,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPELCRFL',2015,'OIL_R',            11.95,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPELCCOAB',2015,'COAB_EA',         0.44,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPELCCOAS',2015,'COAS_EA',         0.44,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPELCCOAL',2015,'COAL_EA',         0.44,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPELCNGA',2015,'NGASTM_R',         4.33,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPELCNGA',2015,'NGACT_R',          4.33,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPELCNGA',2015,'NGACC_R',          4.33,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPELCNGA',2015,'NGACT_N',          4.33,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPELCNGA',2015,'NGACC_N',          4.33,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPELCNGA',2015,'NGAACT_N',         4.33,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPELCNGA',2015,'NGAACC_N',         4.33,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPELCNGA',2015,'NGACC_CCS_N',      4.33,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPTRNDSL',2015,'DSL_EA',           11.95,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPTRNE85',2015,'E85_EA',           -50.8,'#kt/PJout','#accounted for ethanl and gas emission factors');
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPTRNE10',2015,'E10_EA',           6.51,'#kt/PJout','#accounted for ethanl and gas emission factors');
# INSERT INTO "EmissionActivity" VALUES('co2','ethos','IMPTRNCNG',2015,'CNG_EA',           4.33,'#kt/PJout','');
#
# INSERT INTO "EmissionActivity" VALUES('co2','COAB_EA','E_EA_COAB',2015,'COAB',        88.42,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','COAB_EA','E_EA_COAB',2020,'COAB',        88.42,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','COAB_EA','E_EA_COAB',2025,'COAB',        88.42,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','COAB_EA','E_EA_COAB',2030,'COAB',        88.42,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','COAB_EA','E_EA_COAB',2035,'COAB',        88.42,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','COAB_EA','E_EA_COAB',2040,'COAB',        88.42,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','COAB_EA','E_EA_COAB',2045,'COAB',        88.42,'#kt/PJout','');
# INSERT INTO "EmissionActivity" VALUES('co2','COAB_EA','E_EA_COAB',2050,'COAB',        88.42,'#kt/PJout','');
# ...
# INSERT INTO "CostVariable" VALUES(2030,'E_WNDCL6_N ',        2020,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_WNDCL6_N ',        2020,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_WNDCL6_N ',        2020,12.781,'#M$/PJ','');
#
#
# INSERT INTO "CostVariable" VALUES(2025,'E_WNDCL6_N ',        2025,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2030,'E_WNDCL6_N ',        2025,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_WNDCL6_N ',        2025,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_WNDCL6_N ',        2025,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_WNDCL6_N ',        2025,12.781,'#M$/PJ','');
#
# INSERT INTO "CostVariable" VALUES(2030,'E_WNDCL6_N ',        2030,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_WNDCL6_N ',        2030,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_WNDCL6_N ',        2030,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_WNDCL6_N ',        2030,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_WNDCL6_N ',        2030,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_WNDCL6_N ',        2035,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_WNDCL6_N ',        2035,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_WNDCL6_N ',        2035,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_WNDCL6_N ',        2035,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_WNDCL6_N ',        2040,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_WNDCL6_N ',        2040,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_WNDCL6_N ',        2040,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_WNDCL6_N ',        2045,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_WNDCL6_N ',        2045,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_WNDCL6_N ',        2050,12.781,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2015,'E_SOLPV_R ',         2010,13.011,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2020,'E_SOLPV_R ',         2010,13.011,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2025,'E_SOLPV_R ',         2010,13.011,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2030,'E_SOLPV_R ',         2010,13.011,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_SOLPV_R ',         2010,13.011,'#M$/PJ','');
#
#
#
# INSERT INTO "CostVariable" VALUES(2015,'E_SOLTH_R ',         2010,13.011,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2020,'E_SOLTH_R ',         2010,13.011,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2025,'E_SOLTH_R ',         2010,13.011,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2030,'E_SOLTH_R ',         2010,13.011,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_SOLTH_R ',         2010,13.011,'#M$/PJ','');
#
#
#
#
#
#
#
#
#
#
#
# INSERT INTO "CostVariable" VALUES(2020,'E_SOLPVCEN_N ',      2020,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2025,'E_SOLPVCEN_N ',      2020,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2030,'E_SOLPVCEN_N ',      2020,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_SOLPVCEN_N ',      2020,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_SOLPVCEN_N ',      2020,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_SOLPVCEN_N ',      2020,11.111,'#M$/PJ','');
#
# INSERT INTO "CostVariable" VALUES(2025,'E_SOLPVCEN_N ',      2025,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2030,'E_SOLPVCEN_N ',      2025,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_SOLPVCEN_N ',      2025,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_SOLPVCEN_N ',      2025,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_SOLPVCEN_N ',      2025,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_SOLPVCEN_N ',      2025,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2030,'E_SOLPVCEN_N ',      2030,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_SOLPVCEN_N ',      2030,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_SOLPVCEN_N ',      2030,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_SOLPVCEN_N ',      2030,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_SOLPVCEN_N ',      2030,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_SOLPVCEN_N ',      2035,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_SOLPVCEN_N ',      2035,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_SOLPVCEN_N ',      2035,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_SOLPVCEN_N ',      2035,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_SOLPVCEN_N ',      2040,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_SOLPVCEN_N ',      2040,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_SOLPVCEN_N ',      2040,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_SOLPVCEN_N ',      2045,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_SOLPVCEN_N ',      2045,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_SOLPVCEN_N ',      2050,11.111,'#M$/PJ','');
#
#
#
#
#
#
#
#
# INSERT INTO "CostVariable" VALUES(2020,'E_SOLTHCEN_N ',      2020,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2025,'E_SOLTHCEN_N ',      2020,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2030,'E_SOLTHCEN_N ',      2020,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_SOLTHCEN_N ',      2020,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_SOLTHCEN_N ',      2020,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_SOLTHCEN_N ',      2020,11.111,'#M$/PJ','');
#
# INSERT INTO "CostVariable" VALUES(2025,'E_SOLTHCEN_N ',      2025,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2030,'E_SOLTHCEN_N ',      2025,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_SOLTHCEN_N ',      2025,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_SOLTHCEN_N ',      2025,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_SOLTHCEN_N ',      2025,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_SOLTHCEN_N ',      2025,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2030,'E_SOLTHCEN_N ',      2030,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_SOLTHCEN_N ',      2030,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_SOLTHCEN_N ',      2030,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_SOLTHCEN_N ',      2030,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_SOLTHCEN_N ',      2030,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_SOLTHCEN_N ',      2035,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_SOLTHCEN_N ',      2035,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_SOLTHCEN_N ',      2035,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_SOLTHCEN_N ',      2035,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_SOLTHCEN_N ',      2040,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_SOLTHCEN_N ',      2040,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_SOLTHCEN_N ',      2040,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_SOLTHCEN_N ',      2045,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_SOLTHCEN_N ',      2045,11.111,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_SOLTHCEN_N ',      2050,11.111,'#M$/PJ','');
#
#
#
#
#
#
#
#
# INSERT INTO "CostVariable" VALUES(2020,'E_CCR_COALSTM_N ',      2020,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2025,'E_CCR_COALSTM_N ',      2020,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2030,'E_CCR_COALSTM_N ',      2020,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_CCR_COALSTM_N ',      2020,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_CCR_COALSTM_N ',      2020,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_CCR_COALSTM_N ',      2020,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_CCR_COALSTM_N ',      2020,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2025,'E_CCR_COALSTM_N ',      2025,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2030,'E_CCR_COALSTM_N ',      2025,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_CCR_COALSTM_N ',      2025,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_CCR_COALSTM_N ',      2025,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_CCR_COALSTM_N ',      2025,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_CCR_COALSTM_N ',      2025,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2030,'E_CCR_COALSTM_N ',      2030,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_CCR_COALSTM_N ',      2030,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_CCR_COALSTM_N ',      2030,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_CCR_COALSTM_N ',      2030,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_CCR_COALSTM_N ',      2030,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_CCR_COALSTM_N ',      2035,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_CCR_COALSTM_N ',      2035,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_CCR_COALSTM_N ',      2035,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_CCR_COALSTM_N ',      2035,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_CCR_COALSTM_N ',      2040,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_CCR_COALSTM_N ',      2040,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_CCR_COALSTM_N ',      2040,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_CCR_COALSTM_N ',      2045,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_CCR_COALSTM_N ',      2045,1.171,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_CCR_COALSTM_N ',      2050,1.171,'#M$/PJ','');
#
#
#
#
#
#
#
#
# INSERT INTO "CostVariable" VALUES(2020,'E_CCR_COALIGCC_N ',      2020,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2025,'E_CCR_COALIGCC_N ',      2020,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2030,'E_CCR_COALIGCC_N ',      2020,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_CCR_COALIGCC_N ',      2020,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_CCR_COALIGCC_N ',      2020,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_CCR_COALIGCC_N ',      2020,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_CCR_COALIGCC_N ',      2020,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2025,'E_CCR_COALIGCC_N ',      2025,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2030,'E_CCR_COALIGCC_N ',      2025,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_CCR_COALIGCC_N ',      2025,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_CCR_COALIGCC_N ',      2025,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_CCR_COALIGCC_N ',      2025,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_CCR_COALIGCC_N ',      2025,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2030,'E_CCR_COALIGCC_N ',      2030,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_CCR_COALIGCC_N ',      2030,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_CCR_COALIGCC_N ',      2030,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_CCR_COALIGCC_N ',      2030,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_CCR_COALIGCC_N ',      2030,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2035,'E_CCR_COALIGCC_N ',      2035,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_CCR_COALIGCC_N ',      2035,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_CCR_COALIGCC_N ',      2035,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_CCR_COALIGCC_N ',      2035,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2040,'E_CCR_COALIGCC_N ',      2040,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_CCR_COALIGCC_N ',      2040,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_CCR_COALIGCC_N ',      2040,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2045,'E_CCR_COALIGCC_N ',      2045,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_CCR_COALIGCC_N ',      2045,0.618,'#M$/PJ','');
# INSERT INTO "CostVariable" VALUES(2050,'E_CCR_COALIGCC_N ',      2050,0.618,'#M$/PJ','');
#
#
#
#
#
#
#
#
# CREATE TABLE Output_VFlow_Out (
#    scenario text,
#    t_periods integer,
#    t_season text,
#    t_day text,
#    input_comm text,
#    tech text,
#    vintage integer,
#    output_comm text,
#    vflow_out real,
#    PRIMARY KEY(scenario, t_periods, t_season, t_day, input_comm, tech, vintage, output_comm),
#    FOREIGN KEY(t_periods) REFERENCES time_periods(t_periods),
#    FOREIGN KEY(t_season) REFERENCES time_periods(t_periods),
#    FOREIGN KEY(t_day) REFERENCES time_of_day(t_day),
#    FOREIGN KEY(input_comm) REFERENCES commodities(comm_name),
#    FOREIGN KEY(tech) REFERENCES technologies(tech),
#    FOREIGN KEY(vintage) REFERENCES time_periods(t_periods),
#    FOREIGN KEY(output_comm) REFERENCES commodities(comm_name));
#
# CREATE TABLE Output_VFlow_In (
#    scenario text,
#    t_periods integer,
#    t_season text,
#    t_day text,
#    input_comm text,
#    tech text,
#    vintage integer,
#    output_comm text,
#    vflow_in real,
#    PRIMARY KEY(scenario, t_periods, t_season, t_day, input_comm, tech, vintage, output_comm),
#    FOREIGN KEY(t_periods) REFERENCES time_periods(t_periods),
#    FOREIGN KEY(t_season) REFERENCES time_periods(t_periods),
#    FOREIGN KEY(t_day) REFERENCES time_of_day(t_day),
#    FOREIGN KEY(input_comm) REFERENCES commodities(comm_name),
#    FOREIGN KEY(tech) REFERENCES technologies(tech),
#    FOREIGN KEY(vintage) REFERENCES time_periods(t_periods),
#    FOREIGN KEY(output_comm) REFERENCES commodities(comm_name));
#
# CREATE TABLE Output_Capacity (
#    scenario text,
#    t_periods integer,
#    tech text,
#    capacity real,
#    PRIMARY KEY(scenario, t_periods, tech),
#    FOREIGN KEY(t_periods) REFERENCES time_periods(t_periods),
#    FOREIGN KEY(tech) REFERENCES technologies(tech));
#
# CREATE TABLE Output_Emissions (
#    scenario text,
#    t_periods integer,
#    emissions_comm text,
#    tech text,
#    vintage integer,
#    emissions real,
#    PRIMARY KEY(scenario, t_periods, emissions_comm, tech, vintage),
#    FOREIGN KEY(emissions_comm) REFERENCES EmissionActivity(emis_comm),
#    FOREIGN KEY(t_periods) REFERENCES time_periods(t_periods),
#    FOREIGN KEY(tech) REFERENCES technologies(tech)
#    FOREIGN KEY(vintage) REFERENCES time_periods(t_periods));
#
# CREATE TABLE Output_Costs (
#    scenario text,
#    output_name text,
#    tech text,
#    vintage integer,
#    output_cost real,
#    PRIMARY KEY(scenario, output_name, tech, vintage),
#    FOREIGN KEY(tech) REFERENCES technologies(tech),
#    FOREIGN KEY(vintage) REFERENCES time_periods(t_periods));
#
# CREATE TABLE Output_TotalCost (
#    scenario text,
#    total_system_cost real);
#
# CREATE TABLE V_Capacity (
#    scenario text,
#    tech text,
#    vintage integer,
#    capacity real,
#    PRIMARY KEY(scenario, tech, vintage),
#    FOREIGN KEY(vintage) REFERENCES time_periods(t_periods),
#    FOREIGN KEY(tech) REFERENCES technologies(tech));
#
# CREATE TABLE V_ActivityByPeriodAndProcess (
#    scenario text,
#    t_periods integer,
#    tech text,
#    vintage integer,
#    activity real,
#    PRIMARY KEY(scenario, t_periods, tech, vintage),
#    FOREIGN KEY(t_periods) REFERENCES time_periods(t_periods),
#    FOREIGN KEY(tech) REFERENCES technologies(tech)
#    FOREIGN KEY(vintage) REFERENCES time_periods(t_periods));
#
#
# COMMIT;
